# %% [markdown]
# # YOLO Family Benchmark
#
# This notebook evaluates and compares multiple YOLO model variants
# under the experimental configuration used in the research study.
#
# The notebook preserves the original research workflow and is intended
# for reproducible model comparison.
#
# > **Note:** Only the configuration values explicitly marked for change
# > should be modified when running a new experiment.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Stage 0 — Environment Setup
#
# This stage prepares the environment required for training and
# evaluating the YOLO model family.
#
# ### Tasks
#
# - Install required dependencies
# - Import libraries
# - Verify package versions
# - Verify GPU availability

# %%
# !rm -rf /content/sample_data

# %%
from pathlib import Path
from urllib.parse import urlparse
import shutil, subprocess
from google.colab import output
import sys
from pathlib import Path
import logging
import sys
import time
import yaml

# %%
# Install the required packages for the experiment.
def git_update(repo_url="https://github.com/tommyngx/DentalYOLO.git"):
    # %cd /content
    repo_name = Path(urlparse(repo_url).path).stem
    target = Path.cwd() / repo_name
    if target.exists():
        shutil.rmtree(target)  # remove
    subprocess.run(["git", "clone", repo_url, str(target)], check=True)
    return target
git_update("https://github.com/tommyngx/DentalYOLO.git")
# Out:
# /content
# PosixPath('/content/DentalYOLO')

# %%
# %cd /content/DentalYOLO
# %pip install -qr requirements.txt  # install
# Out:
# /content/DentalYOLO
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 38.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 23.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 852.4/852.4 kB 57.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 63.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 112.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 98.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 913.3/913.3 kB 65.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 6.4 MB/s eta 0:00:00

# %%
# Verify the library versions used by the experiment.
# Keep these versions consistent when reproducing the reported results.
CUSTOM_ROOT = Path("/content/DentalYOLO/ultralytics")
for m in list(sys.modules):
    if m.startswith("ultralytics"):
        del sys.modules[m]
sys.path.insert(0, str(CUSTOM_ROOT))
import ultralytics
from ultralytics import YOLO
print("Using ultralytics from:", ultralytics.__file__)
logger = logging.getLogger("ultralytics")
if len(logger.handlers) > 1:
    logger.handlers = logger.handlers[:1]
logger.propagate = False
print("Number of ultralytics handlers after fix:", len(logger.handlers))
print(ultralytics.__version__)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Using ultralytics from: /content/DentalYOLO/ultralytics/__init__.py
# Number of ultralytics handlers after fix: 1
# 8.4.75

# %%
from pathlib import Path
from ultralytics import YOLO
import time
T_START = time.time()

# %% [markdown]
# ## Stage 1 — Configuration
#
# This stage defines the models, datasets, training parameters,
# and benchmark settings used for the YOLO family comparison.
#
# ### Tasks
#
# - Select dataset
# - Select YOLO model variants
# - Configure training parameters
# - Configure evaluation parameters
# - Configure output paths

# %%
import os
from dataclasses import dataclass

# %%
@dataclass
class Config:
    # PROJECT
    project_dir: str = "/content/drive/MyDrive/Your-Project"
    experiment_name: str = "experiment_name"

    # DATA
    # Change this to the dataset you want to use.
    dataset_name: str = "dataset_name"
    # Change this to your dataset ZIP file.
    zip_dataset: str = os.path.join(
        project_dir,
        "datasets",
        f"{dataset_name}.zip"
    )

    # MODEL
    # Change this to select the model used in the experiment.
    model_name: str = "yolov8n"

    # TRAINING
    # Only epochs is set explicitly.
    # All other training settings come from the framework defaults.
    epochs: int = 100 # Number of training epochs.
    imgsz: int = 640 # Training batch size.
    batchsize: int = 8 # Input image size used during training and evaluation.
    seed: int = 2026 # Random seed used for reproducibility.

cfg = Config()

# PATH SETUP
cfg.output_root = os.path.join(cfg.project_dir, "output")

cfg.output_dir = os.path.join(
    cfg.output_root,
    cfg.dataset_name,
    cfg.model_name,
)
cfg.result_dir = os.path.join(
    cfg.output_dir,
    cfg.experiment_name,
)
# This file defines the dataset paths, number of classes, and class names.
cfg.data_dir = os.path.join("/content", cfg.dataset_name)
cfg.yaml_path = os.path.join(cfg.data_dir, "data.yaml")
# create dirs
os.makedirs(cfg.output_dir, exist_ok=True)

print("Output dir:", cfg.output_dir)
print("Data dir:", cfg.data_dir)
# Out:
# Output dir: /content/drive/MyDrive/Oral_Disease_Detection/output/dental_opg_2024/yolov8m
# Data dir: /content/dental_opg_2024

# %% [markdown]
# ## Stage 2 — Dataset Preparation
#
# This stage prepares and verifies the dataset before model training.
#
# ### Tasks
#
# - Locate the dataset
# - Read the dataset configuration
# - Verify image and label directories
# - Check dataset structure
# - Prepare the dataset for training and evaluation

# %%
# Extract the dataset ZIP archive if it has not already been prepared.
# !unzip -q {cfg.zip_dataset} -d /content/
print("Dataset ready:", cfg.data_dir)
# Out:
# Dataset ready: /content/dental_opg_2024

# %%
# Verify that the expected image and label directories are available.
assert os.path.exists(cfg.yaml_path), "Missing data.yaml"
assert os.path.exists(os.path.join(cfg.data_dir, "train")), "Missing train folder"
assert os.path.exists(os.path.join(cfg.data_dir, "val")), "Missing val folder"

print("Dataset structure OK ✅")
# Out:
# Dataset structure OK ✅

# %%
from ultralytics import YOLO
from ultralytics import settings

settings.update({"datasets_dir": ""})

# %%
import yaml

def fix_data_yaml(yaml_path, dataset_name):
    with open(yaml_path, "r") as f:
        data = yaml.safe_load(f)

    # Update path
    new_path = f"/content/{dataset_name}"
    data["path"] = new_path

    with open(yaml_path, "w") as f:
        yaml.safe_dump(data, f, sort_keys=False)

    print(f"Updated path -> {new_path}")
    return data

fix_data_yaml(cfg.yaml_path, cfg.dataset_name)
# Out:
# Updated path -> /content/dental_opg_2024
# {'path': '/content/dental_opg_2024',
#  'train': 'train/images',
#  'val': 'val/images',
#  'test': 'test/images',
#  'nc': 6,
#  'names': {0: 'Healthy teeth',
#   1: 'Infection',
#   2: 'Impacted teeth',
#   3: 'Broken-down crown or root (BDC/BDR)',
#   4: 'Fractured teeth',
#   5: 'Caries'}}

# %% [markdown]
# ## Stage 3 — Model Training
#
# This stage trains each configured YOLO model using the same
# experimental protocol.
#
# ### Tasks
#
# - Train each model
# - Save training results
# - Record experiment configuration

# %%
# !python scripts/train.py \
    --model {cfg.model_name} \
    --data {cfg.yaml_path} \
    --epochs {cfg.epochs} \
    --batch {cfg.batchsize} \
    --imgsz {cfg.imgsz} \
    --seed {cfg.seed} \
    --project {cfg.output_dir} \
    --name {cfg.experiment_name} \
    --device 0
# Out:
# Model      : yolov8m
# Dataset    : /content/dental_opg_2024/data.yaml
# Experiment : exp5_e100_b16
#
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8m.pt to 'yolov8m.pt': 100% ━━━━━━━━━━━━ 49.7MB 143.6MB/s 0.3s
# New https://pypi.org/project/ultralytics/8.4.112 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.75 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/dental_opg_2024/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8m.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=exp5_e100_b16, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/Oral_Disease_Detection/output/dental_opg_2024/yolov8m, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/.shortcut-targets-by-id/16SySpbjxLUJpy70huvigKBEvP90dySpm/Oral_Disease_Detection/output/dental_opg_2024/yolov8m/exp5_e100_b16, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=2026, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 23.7MB/s 0.0s
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3779170  ultralytics.nn.modules.head.Detect           [6, 16, None, [192, 384, 576]]
# Model summary: 170 layers, 25,859,794 parameters, 25,859,778 gradients, 79.1 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 78.7MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1002.0±450.1 MB/s, size: 42.3 KB)
# train: Scanning /content/dental_opg_2024/train/labels... 558 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 558/558 2.1Kit/s 0.3s
# train: New cache created: /content/dental_opg_2024/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 618.2±414.0 MB/s, size: 39.0 KB)
# val: Scanning /content/dental_opg_2024/val/labels... 23 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 23/23 1.7Kit/s 0.0s
# val: New cache created: /content/dental_opg_2024/val/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# Plotting labels to /content/drive/.shortcut-targets-by-id/16SySpbjxLUJpy70huvigKBEvP90dySpm/Oral_Disease_Detection/output/dental_opg_2024/yolov8m/exp5_e100_b16/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/.shortcut-targets-by-id/16SySpbjxLUJpy70huvigKBEvP90dySpm/Oral_Disease_Detection/output/dental_opg_2024/yolov8m/exp5_e100_b16
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      6
0.634
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      6.37G     0.5977     0.3596      0.907        298        640: 100% ━━━━━━━━━━━━ 35/35 1.9it/s 18.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.9it/s 0.3s
#                    all         23        115      0.928      0.886      0.935      0.632
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      6.37G     0.6281     0.3567     0.9564        124        640: 100% ━━━━━━━━━━━━ 35/35 1.9it/s 18.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.4it/s 0.2s
#                    all         23        115      0.906      0.911      0.929      0.633
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      6.37G     0.5541     0.3062       0.91        127        640: 100% ━━━━━━━━━━━━ 35/35 1.9it/s 18.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.7it/s 0.3s
#                    all         23        115      0.916      0.871      0.919      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      6.37G     0.5392     0.3009     0.9035        121        640: 100% ━━━━━━━━━━━━ 35/35 2.0it/s 17.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.7it/s 0.3s
#                    all         23        115      0.924       0.83      0.912      0.602
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      6.37G     0.5297     0.2981     0.8995        137        640: 100% ━━━━━━━━━━━━ 35/35 1.9it/s 18.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all         23        115      0.896      0.861      0.916      0.617
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      6.37G     0.5155     0.2917     0.8944        147        640: 100% ━━━━━━━━━━━━ 35/35 1.9it/s 18.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.1it/s 0.2s
#                    all         23        115      0.913      0.876      0.922      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      6.37G     0.5014     0.2866     0.8917        120        640: 100% ━━━━━━━━━━━━ 35/35 1.9it/s 18.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all         23        115      0.922      0.888      0.923      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      6.37G     0.4873     0.2778     0.8879        132        640: 100% ━━━━━━━━━━━━ 35/35 1.9it/s 18.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.3it/s 0.3s
#                    all         23        115      0.894      0.914      0.924      0.632
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      6.37G     0.4952     0.2771     0.8852        112        640: 100% ━━━━━━━━━━━━ 35/35 2.0it/s 17.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.4it/s 0.2s
#                    all         23        115      0.913       0.91      0.926      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      6.37G     0.4724     0.2693     0.8716        129        640: 100% ━━━━━━━━━━━━ 35/35 2.0it/s 17.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.4it/s 0.2s
#                    all         23        115      0.918      0.912      0.923      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# ...
#   100                    model.15.cv2.bn.bias         BatchNorm2d     False         192               [192]    -0.557     0.719        float32
#   101            model.15.m.0.cv1.conv.weight              Conv2d     False       82944      [96, 96, 3, 3]  -0.00139    0.0194        float32
#   102              model.15.m.0.cv1.bn.weight         BatchNorm2d     False          96                [96]     0.826     0.111        float32
#   102                model.15.m.0.cv1.bn.bias         BatchNorm2d     False          96                [96]    -0.714     0.503        float32
#   103            model.15.m.0.cv2.conv.weight              Conv2d     False       82944      [96, 96, 3, 3]  -0.00192    0.0176        float32
#   104              model.15.m.0.cv2.bn.weight         BatchNorm2d     False          96                [96]     0.834     0.127        float32
#   104                model.15.m.0.cv2.bn.bias         BatchNorm2d     False          96                [96]    -0.628     0.486        float32
#   105            model.15.m.1.cv1.conv.weight              Conv2d     False       82944      [96, 96, 3, 3]  -0.00229    0.0163        float32
#   106              model.15.m.1.cv1.bn.weight         BatchNorm2d     False          96                [96]     0.808     0.152        float32
#   106                model.15.m.1.cv1.bn.bias         BatchNorm2d     False          96                [96]    -0.812     0.492        float32
#   107            model.15.m.1.cv2.conv.weight              Conv2d     False       82944      [96, 96, 3, 3]  -0.00123    0.0149        float32
#   108              model.15.m.1.cv2.bn.weight         BatchNorm2d     False          96                [96]     0.969      0.25        float32
#   108                model.15.m.1.cv2.bn.bias         BatchNorm2d     False          96                [96]    -0.257     0.475        float32
#   109                    model.16.conv.weight              Conv2d     False      331776    [192, 192, 3, 3] -0.000542   0.00967        float32
#   110                      model.16.bn.weight         BatchNorm2d     False         192               [192]     0.862     0.159        float32
#   110                        model.16.bn.bias         BatchNorm2d     False         192               [192]    -0.475     0.264        float32
#   111                                model.17              Concat     False           0                  []         -         -              -
#   112                model.18.cv1.conv.weight              Conv2d     False      221184    [384, 576, 1, 1]  -0.00104    0.0108        float32
#   113                  model.18.cv1.bn.weight         BatchNorm2d     False         384               [384]     0.991     0.124        float32
#   113                    model.18.cv1.bn.bias         BatchNorm2d     False         384               [384]    -0.496     0.323        float32
#   114                model.18.cv2.conv.weight              Conv2d     False      294912    [384, 768, 1, 1]  -0.00131   0.00882        float32
#   115                  model.18.cv2.bn.weight         BatchNorm2d     False         384               [384]     0.931     0.277        float32
#   115                    model.18.cv2.bn.bias         BatchNorm2d     False         384               [384]    -0.662     0.393        float32
#   116            model.18.m.0.cv1.conv.weight              Conv2d     False      331776    [192, 192, 3, 3] -0.000738   0.00752        float32
#   117              model.18.m.0.cv1.bn.weight         BatchNorm2d     False         192               [192]     0.985     0.158        float32
#   117                model.18.m.0.cv1.bn.bias         BatchNorm2d     False         192               [192]    -0.762     0.374        float32
#   118            model.18.m.0.cv2.conv.weight              Conv2d     False      331776    [192, 192, 3, 3] -0.000825   0.00707        float32
#   119              model.18.m.0.cv2.bn.weight         BatchNorm2d     False         192               [192]      1.02     0.122        float32
#   119                model.18.m.0.cv2.bn.bias         BatchNorm2d     False         192               [192]    -0.695     0.383        float32
#   120            model.18.m.1.cv1.conv.weight              Conv2d     False      331776    [192, 192, 3, 3] -0.000687   0.00602        float32
#   121              model.18.m.1.cv1.bn.weight         BatchNorm2d     False         192               [192]     0.973     0.156        float32
#   121                model.18.m.1.cv1.bn.bias         BatchNorm2d     False         192               [192]    -0.784     0.273        float32
#   122            model.18.m.1.cv2.conv.weight              Conv2d     False      331776    [192, 192, 3, 3] -0.000776   0.00608        float32
#   123              model.18.m.1.cv2.bn.weight         BatchNorm2d     False         192               [192]      1.26     0.171        float32
#   123                model.18.m.1.cv2.bn.bias         BatchNorm2d     False         192               [192]    -0.423     0.312        float32
#   124                    model.19.conv.weight              Conv2d     False  1.3271e+06    [384, 384, 3, 3]  -0.00013   0.00298        float32
#   125                      model.19.bn.weight         BatchNorm2d     False         384               [384]     0.913     0.104        float32
#   125                        model.19.bn.bias         BatchNorm2d     False         384               [384]    -0.325     0.112        float32
#   126                                model.20              Concat     False           0                  []         -         -              -
#   127                model.21.cv1.conv.weight              Conv2d     False      552960    [576, 960, 1, 1] -0.000413   0.00464        float32
#   128                  model.21.cv1.bn.weight         BatchNorm2d     False         576               [576]      1.03     0.115        float32
#   128                    model.21.cv1.bn.bias         BatchNorm2d     False         576               [576]    -0.323     0.196        float32
#   129                model.21.cv2.conv.weight              Conv2d     False      663552   [576, 1152, 1, 1] -0.000355   0.00389        float32
#   130                  model.21.cv2.bn.weight         BatchNorm2d     False         576               [576]       1.1     0.193        float32
#   130                    model.21.cv2.bn.bias         BatchNorm2d     False         576               [576]    -0.333     0.167        float32
#   131            model.21.m.0.cv1.conv.weight              Conv2d     False      746496    [288, 288, 3, 3] -0.000253   0.00363        float32
#   132              model.21.m.0.cv1.bn.weight         BatchNorm2d     False         288               [288]      1.11     0.119        float32
#   132                model.21.m.0.cv1.bn.bias         BatchNorm2d     False         288               [288]    -0.402     0.216        float32
#   133            model.21.m.0.cv2.conv.weight              Conv2d     False      746496    [288, 288, 3, 3] -0.000385   0.00352        float32
#   134              model.21.m.0.cv2.bn.weight         BatchNorm2d     False         288               [288]      1.04     0.117        float32
#   134                model.21.m.0.cv2.bn.bias         BatchNorm2d     False         288               [288]    -0.505     0.234        float32
#   135            model.21.m.1.cv1.conv.weight              Conv2d     False      746496    [288, 288, 3, 3] -0.000222   0.00319        float32
#   136              model.21.m.1.cv1.bn.weight         BatchNorm2d     False         288               [288]      1.09     0.119        float32
#   136                model.21.m.1.cv1.bn.bias         BatchNorm2d     False         288               [288]    -0.456     0.161        float32
#   137            model.21.m.1.cv2.conv.weight              Conv2d     False      746496    [288, 288, 3, 3] -0.000329   0.00312        float32
#   138              model.21.m.1.cv2.bn.weight         BatchNorm2d     False         288               [288]      1.26      0.12        float32
#   138                model.21.m.1.cv2.bn.bias         BatchNorm2d     False         288               [288]    -0.252     0.132        float32
#   139            model.22.cv2.0.0.conv.weight              Conv2d     False      110592     [64, 192, 3, 3]  -0.00112    0.0127        float32
#   140              model.22.cv2.0.0.bn.weight         BatchNorm2d     False          64                [64]      1.04     0.452        float32
#   140                model.22.cv2.0.0.bn.bias         BatchNorm2d     False          64                [64]    -0.022      0.86        float32
#   141            model.22.cv2.0.1.conv.weight              Conv2d     False       36864      [64, 64, 3, 3] -0.000512    0.0156        float32
#   142              model.22.cv2.0.1.bn.weight         BatchNorm2d     False          64                [64]      2.23     0.921        float32
#   142                model.22.cv2.0.1.bn.bias         BatchNorm2d     False          64                [64]     0.963     0.545        float32
#   143                 model.22.cv2.0.2.weight              Conv2d     False        4096      [64, 64, 1, 1]   -0.0127    0.0587        float32
#   143                   model.22.cv2.0.2.bias              Conv2d     False          64                [64]     0.993      1.21        float32
#   144            model.22.cv2.1.0.conv.weight              Conv2d     False      221184     [64, 384, 3, 3] -0.000568   0.00825        float32
#   145              model.22.cv2.1.0.bn.weight         BatchNorm2d     False          64                [64]      1.17     0.452        float32
#   145                model.22.cv2.1.0.bn.bias         BatchNorm2d     False          64                [64]    0.0147     0.685        float32
#   146            model.22.cv2.1.1.conv.weight              Conv2d     False       36864      [64, 64, 3, 3] -0.000496    0.0132        float32
#   147              model.22.cv2.1.1.bn.weight         BatchNorm2d     False          64                [64]      2.49      0.67        float32
#   147                model.22.cv2.1.1.bn.bias         BatchNorm2d     False          64                [64]     0.925     0.465        float32
#   148                 model.22.cv2.1.2.weight              Conv2d     False        4096      [64, 64, 1, 1]   -0.0106    0.0529        float32
#   148                   model.22.cv2.1.2.bias              Conv2d     False          64                [64]     0.984     0.975        float32
#   149            model.22.cv2.2.0.conv.weight              Conv2d     False      331776     [64, 576, 3, 3] -0.000293   0.00452        float32
#   150              model.22.cv2.2.0.bn.weight         BatchNorm2d     False          64                [64]      1.32     0.283        float32
#   150                model.22.cv2.2.0.bn.bias         BatchNorm2d     False          64                [64]   -0.0872      0.52        float32
#   151            model.22.cv2.2.1.conv.weight              Conv2d     False       36864      [64, 64, 3, 3]  0.000452   0.00866        float32
#   152              model.22.cv2.2.1.bn.weight         BatchNorm2d     False          64                [64]      3.11     0.505        float32
#   152                model.22.cv2.2.1.bn.bias         BatchNorm2d     False          64                [64]     0.884     0.495        float32
#   153                 model.22.cv2.2.2.weight              Conv2d     False        4096      [64, 64, 1, 1]  -0.00245    0.0454        float32
#   153                   model.22.cv2.2.2.bias              Conv2d     False          64                [64]     0.994     0.838        float32
#   154            model.22.cv3.0.0.conv.weight              Conv2d     False      331776    [192, 192, 3, 3]  -0.00112   0.00971        float32
#   155              model.22.cv3.0.0.bn.weight         BatchNorm2d     False         192               [192]     0.879      0.29        float32
#   155                model.22.cv3.0.0.bn.bias         BatchNorm2d     False         192               [192]    -0.334     0.512        float32
#   156            model.22.cv3.0.1.conv.weight              Conv2d     False      331776    [192, 192, 3, 3]  -0.00129   0.00853        float32
#   157              model.22.cv3.0.1.bn.weight         BatchNorm2d     False         192               [192]      1.98     0.643        float32
#   157                model.22.cv3.0.1.bn.bias         BatchNorm2d     False         192               [192]     0.839      1.03        float32
#   158                 model.22.cv3.0.2.weight              Conv2d     False        1152      [6, 192, 1, 1]   -0.0196    0.0577        float32
#   158                   model.22.cv3.0.2.bias              Conv2d     False           6                 [6]     -8.95   0.00699        float32
#   159            model.22.cv3.1.0.conv.weight              Conv2d     False      663552    [192, 384, 3, 3] -0.000389   0.00523        float32
#   160              model.22.cv3.1.0.bn.weight         BatchNorm2d     False         192               [192]      1.05     0.291        float32
#   160                model.22.cv3.1.0.bn.bias         BatchNorm2d     False         192               [192]      -0.2     0.507        float32
#   161            model.22.cv3.1.1.conv.weight              Conv2d     False      331776    [192, 192, 3, 3] -0.000975   0.00553        float32
#   162              model.22.cv3.1.1.bn.weight         BatchNorm2d     False         192               [192]       2.1     0.706        float32
#   162                model.22.cv3.1.1.bn.bias         BatchNorm2d     False         192               [192]     0.777      0.92        float32
#   163                 model.22.cv3.1.2.weight              Conv2d     False        1152      [6, 192, 1, 1]   -0.0223    0.0459        float32
#   163                   model.22.cv3.1.2.bias              Conv2d     False           6                 [6]     -7.59   0.00758        float32
#   164            model.22.cv3.2.0.conv.weight              Conv2d     False      995328    [192, 576, 3, 3] -8.57e-05   0.00283        float32
#   165              model.22.cv3.2.0.bn.weight         BatchNorm2d     False         192               [192]       1.1     0.231        float32
#   165                model.22.cv3.2.0.bn.bias         BatchNorm2d     False         192               [192]    -0.237     0.321        float32
#   166            model.22.cv3.2.1.conv.weight              Conv2d     False      331776    [192, 192, 3, 3]  -0.00066   0.00381        float32
#   167              model.22.cv3.2.1.bn.weight         BatchNorm2d     False         192               [192]      2.13     0.478        float32
#   167                model.22.cv3.2.1.bn.bias         BatchNorm2d     False         192               [192]      0.83     0.914        float32
#   168                 model.22.cv3.2.2.weight              Conv2d     False        1152      [6, 192, 1, 1]   -0.0276    0.0445        float32
#   168                   model.22.cv3.2.2.bias              Conv2d     False           6                 [6]      -6.2   0.00159        float32
#   169                model.22.dfl.conv.weight              Conv2d     False          16       [1, 16, 1, 1]       7.5      4.76        float32
# Model summary: 170 layers, 25,859,794 parameters, 0 gradients, 79.1 GFLOPs
# Saved model summary: /content/drive/.shortcut-targets-by-id/16SySpbjxLUJpy70huvigKBEvP90dySpm/Oral_Disease_Detection/output/dental_opg_2024/yolov8m/exp5_e100_b16/model_summary.txt
# Saved environment: /content/drive/.shortcut-targets-by-id/16SySpbjxLUJpy70huvigKBEvP90dySpm/Oral_Disease_Detection/output/dental_opg_2024/yolov8m/exp5_e100_b16/environment.txt
# Saved command: /content/drive/.shortcut-targets-by-id/16SySpbjxLUJpy70huvigKBEvP90dySpm/Oral_Disease_Detection/output/dental_opg_2024/yolov8m/exp5_e100_b16/train_command.txt
#
# Training finished in 36.24 minutes
# Results saved to: /content/drive/.shortcut-targets-by-id/16SySpbjxLUJpy70huvigKBEvP90dySpm/Oral_Disease_Detection/output/dental_opg_2024/yolov8m/exp5_e100_b16

# %% [markdown]
# ## History train

# %%
import os
import math
import matplotlib.pyplot as plt
import pandas as pd

# LOAD TRAINING HISTORY
history_path = os.path.join(cfg.result_dir, "results.csv")
df = pd.read_csv(history_path)


# LOSS MAPPING
LOSS_MAPPING = {
    "box_loss":  "Box Loss",
    "giou_loss": "GIoU Loss",
    "cls_loss":  "Classification Loss",
    "dfl_loss":  "DFL Loss",
    "l1_loss":   "L1 Loss",
}

losses = []
for loss in LOSS_MAPPING:
    train_col = f"train/{loss}"
    if train_col in df.columns:
        losses.append(loss)

# FIGURE
n_loss = len(losses)
n_cols = max(3, n_loss)
fig, axs = plt.subplots(2,n_cols,figsize=(6 * n_cols, 10),)

# If only one column, convert to 2D array
if n_cols == 1:
    axs = axs.reshape(2, 1)

# LOSS CURVES
for i, loss in enumerate(losses):
    train_col = f"train/{loss}"
    val_col = f"val/{loss}"
    ax = axs[0, i]
    if train_col in df.columns:
        ax.plot(df[train_col], label="Train")
    if val_col in df.columns:
        ax.plot(df[val_col], label="Validation")
    ax.set_title(LOSS_MAPPING[loss])
    ax.set_xlabel("Epoch")
    ax.grid(True)
    ax.legend()

# Hide unused loss subplots
for i in range(len(losses), n_cols):
    axs[0, i].axis("off")

# METRICS
metric_plots = [
    (
        "mAP",
        [
            ("metrics/mAP50(B)", "mAP50"),
            ("metrics/mAP50-95(B)", "mAP50-95"),
        ],
    ),

    (
        "Recall",
        [
            ("metrics/recall(B)", "Recall"),
        ],
    ),

    (
        "Precision",
        [
            ("metrics/precision(B)", "Precision"),
        ],
    ),
]

for i, (title, curves) in enumerate(metric_plots):
    ax = axs[1, i]
    for column, label in curves:
        if column in df.columns:
            ax.plot(df[column], label=label)
    ax.set_title(title)
    ax.set_xlabel("Epoch")
    ax.grid(True)
    ax.legend()

# Hide unused metric subplots
for i in range(len(metric_plots), n_cols):
    axs[1, i].axis("off")

plt.suptitle(f"{cfg.model_name} | {cfg.dataset_name}",fontsize=16,)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Stage 4 — Model Validation
#
# This stage evaluates the trained model using the validation/test
# configuration defined in the experiment.
#
# ### Tasks
#
# - Run model validation
# - Collect detection metrics
# - Inspect validation results

# %%
# !python scripts/validate.py \
    --data {cfg.yaml_path} \
    --project {cfg.output_dir} \
    --name {cfg.experiment_name} \
    --batch {cfg.batchsize} \
    --imgsz {cfg.imgsz} \
    --device 0
# Out:
# Model      : /content/drive/MyDrive/Oral_Disease_Detection/output/dental_opg_2024/yolov8m/exp5_e100_b16/weights/best.pt
# Dataset    : /content/dental_opg_2024/data.yaml
# Experiment : exp5_e100_b16
#
# Ultralytics 8.4.75 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 93 layers, 25,843,234 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 76.7±114.7 MB/s, size: 39.9 KB)
# val: Scanning /content/dental_opg_2024/test/labels... 23 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 23/23 902.3it/s 0.0s
# val: New cache created: /content/dental_opg_2024/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         23        102      0.836      0.906      0.906      0.656
#          Healthy teeth         14         26      0.907      0.753      0.888      0.681
#              Infection          2          5      0.704          1      0.898      0.692
#         Impacted teeth          7         12      0.888          1      0.937      0.679
#        Fractured teeth          4          5      0.766          1      0.962      0.606
#                 Caries         23         54      0.913      0.778      0.845      0.623
# Speed: 3.6ms preprocess, 28.5ms inference, 0.0ms loss, 1.6ms postprocess per image
# Saving /content/drive/.shortcut-targets-by-id/16SySpbjxLUJpy70huvigKBEvP90dySpm/Oral_Disease_Detection/output/dental_opg_2024/yolov8m/exp5_e100_b16/validation/predictions.json...
# Results saved to /content/drive/.shortcut-targets-by-id/16SySpbjxLUJpy70huvigKBEvP90dySpm/Oral_Disease_Detection/output/dental_opg_2024/yolov8m/exp5_e100_b16/validation
#
# Validation Results
# ----------------------------------------
# mAP50       : 0.9060
# mAP50-95    : 0.6564
# Precision   : 0.8357
# Recall      : 0.9061
#
# Results saved to: /content/drive/.shortcut-targets-by-id/16SySpbjxLUJpy70huvigKBEvP90dySpm/Oral_Disease_Detection/output/dental_opg_2024/yolov8m/exp5_e100_b16/validation

# %% [markdown]
# ## Stage 5 — COCO Evaluation
#
# This stage performs COCO-style evaluation to obtain the detection
# metrics used for research comparison.
#
# ### Tasks
#
# - Prepare ground-truth annotations
# - Convert predictions to COCO format
# - Run COCO evaluation
# - Collect AP metrics

# %%
# !python scripts/coco_evaluate.py \
    --data {cfg.yaml_path} \
    --project {cfg.output_dir} \
    --name {cfg.experiment_name}
# Out:
# Generating test_coco_gt.json...
# Saved COCO GT: /content/drive/MyDrive/Oral_Disease_Detection/output/dental_opg_2024/yolov8m/exp5_e100_b16/validation/test_coco_gt.json
# Images      : 23
# Annotations : 102
# Categories  : 6
# Sample image_id: '104_jpg.rf.05501644f89b63b3f9ba38f2c2436c75' (type: str)
# [exp5_e100_b16] Predictions: 121
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.645
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.890
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.820
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.646
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.413
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.712
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.712
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.712
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.700
#
# Saved COCO metrics: /content/drive/MyDrive/Oral_Disease_Detection/output/dental_opg_2024/yolov8m/exp5_e100_b16/validation/coco_metrics.csv
#
# COCO evaluation completed.
# Results saved to: /content/drive/MyDrive/Oral_Disease_Detection/output/dental_opg_2024/yolov8m/exp5_e100_b16/validation/coco_metrics.csv

# %% [markdown]
# ## Benchmark

# %%
# !python scripts/benchmark.py \
    --project {cfg.output_dir} \
    --name {cfg.experiment_name} \
    --imgsz {cfg.imgsz} \
    --batch 1 \
    --device 0 \
    --half
# Out:
# Saved benchmark: /content/drive/MyDrive/Oral_Disease_Detection/output/dental_opg_2024/yolov8m/exp5_e100_b16/validation/benchmark.csv
#
# Benchmark completed.
# Results saved to: /content/drive/MyDrive/Oral_Disease_Detection/output/dental_opg_2024/yolov8m/exp5_e100_b16/validation/benchmark.csv
